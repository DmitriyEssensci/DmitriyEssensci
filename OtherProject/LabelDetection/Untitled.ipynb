# %%
import tensorflow as tf
import urllib.request
import os
import cv2
import numpy  as np
from scipy import misc
import matplotlib.pyplot as plt
tf.test.gpu_device_name()
import tensorflow as tf
import tensorflow_datasets as tfds
from pathlib import Path
from IPython.display import Image, display
from tensorflow.keras.preprocessing.image import load_img
import PIL
from PIL import ImageOps
from tensorflow import keras
import numpy as np
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras import layers
import random
from tensorflow.keras import metrics
import pandas as pd

# %%
tf.test.is_gpu_available(
    cuda_only=False, min_cuda_compute_capability=None
)
# Out:
# WARNING:tensorflow:From C:\Users\DSTARA~1\AppData\Local\Temp/ipykernel_24048/501681495.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
import os
from subprocess import run, STDOUT, PIPE
import pandas as pd
L = 0
all_files = []
name = []
path = "\\\\192.168.21.132\gt450-images-r\LRC"
cmd = 'C:/Program Files/RCUD/b_label_function/application/b_label_function.exe'
for root, dirs, files in os.walk(path):
    for file in files:
        if file.endswith(".svs"):
            L+=1 
            all_files.append(path)
            name.append(name_svs)
            fullpath = path + name_svs
            path = root
            name_svs = file
            print(path + '\\' +  name_svs, L )
# Out:
# \\192.168.21.132\gt450-images-r\LRC\2021.08.13\LRC.19.1-2.#1\1-2-2_20.svs 1
# \\192.168.21.132\gt450-images-r\LRC\2021.08.13\LRC.19.10-22.#7\10.#1\10-2_14.svs 2
# \\192.168.21.132\gt450-images-r\LRC\2021.08.13\LRC.19.10-22.#7\11-16.#2\11-16-2_12.svs 3
# \\192.168.21.132\gt450-images-r\LRC\2021.08.13\LRC.19.10-22.#7\11-16.#2\11-16-2_13.svs 4
# \\192.168.21.132\gt450-images-r\LRC\2021.08.13\LRC.19.10-22.#7\17-18.#2\17-18-2_10.svs 5
# \\192.168.21.132\gt450-images-r\LRC\2021.08.13\LRC.19.10-22.#7\17-18.#2\17-18-2_11.svs 6
# \\192.168.21.132\gt450-images-r\LRC\2021.08.13\LRC.19.10-22.#7\19-22.#1\19-22-2_9.svs 7
# \\192.168.21.132\gt450-images-r\LRC\2021.08.13\LRC.19.10-22.#7\21-22.#1\21-22-2_8.svs 8
# \\192.168.21.132\gt450-images-r\LRC\2021.08.13\LRC.19.105-06.#2\105-1_30.svs 9
# \\192.168.21.132\gt450-images-r\LRC\2021.08.13\LRC.19.105-06.#2\106-1_29.svs 10
# \\192.168.21.132\gt450-images-r\LRC\2021.08.13\LRC.19.107-12.#3\107-12-1_24.svs 11
# ...

# %%
tag=  []
tag = name
DIR = []
DIR = all_files
df = pd.DataFrame({'dir':DIR ,'name':tag })
df
# Out:
#                                                     dir  \
# 0                   \\192.168.21.132\gt450-images-r\LRC
# 1     \\192.168.21.132\gt450-images-r\LRC\2021.08.13...
# 2     \\192.168.21.132\gt450-images-r\LRC\2021.08.13...
# 3     \\192.168.21.132\gt450-images-r\LRC\2021.08.13...
# 4     \\192.168.21.132\gt450-images-r\LRC\2021.08.13...
# ...                                                 ...
# 7919  \\192.168.21.132\gt450-images-r\LRC\2021.10.26...
# 7920  \\192.168.21.132\gt450-images-r\LRC\2021.10.26...
# 7921  \\192.168.21.132\gt450-images-r\LRC\2021.10.26...
# 7922  \\192.168.21.132\gt450-images-r\LRC\2021.10.26...
# 7923  \\192.168.21.132\gt450-images-r\LRC\2021.10.26...
#
#                            name
# 0     LRC.2019.1350-59.#5.5.svs
# 1                  1-2-2_20.svs
# 2                   10-2_14.svs
# 3                11-16-2_12.svs
# 4                11-16-2_13.svs
# ...                         ...
# 7919    LRC_2018_34011_#1_1.svs
# ...

# %%
direct = df['dir'].str.split("\\", 7, expand=True)
#direct = direct.iloc[:7550, [0, 1,2,3]]

# %%
direct
# Out:
#      0  1                2               3    4           5  \
# 0           192.168.21.132  gt450-images-r  LRC        None
# 1           192.168.21.132  gt450-images-r  LRC  2021.08.13
# 2           192.168.21.132  gt450-images-r  LRC  2021.08.13
# 3           192.168.21.132  gt450-images-r  LRC  2021.08.13
# 4           192.168.21.132  gt450-images-r  LRC  2021.08.13
# ...  .. ..             ...             ...  ...         ...
# 7919        192.168.21.132  gt450-images-r  LRC  2021.10.26
# 7920        192.168.21.132  gt450-images-r  LRC  2021.10.26
# 7921        192.168.21.132  gt450-images-r  LRC  2021.10.26
# 7922        192.168.21.132  gt450-images-r  LRC  2021.10.26
# 7923        192.168.21.132  gt450-images-r  LRC  2021.10.26
#
#                       6         7
# 0                  None      None
# 1         LRC.19.1-2.#1      None
# 2       LRC.19.10-22.#7     10.#1
# 3       LRC.19.10-22.#7  11-16.#2
# 4       LRC.19.10-22.#7  11-16.#2
# ...

# %%
direct = dataframe['directory'].str.split("\\", 3, expand=True)
direct = direct.iloc[:7550, [2, 3]].rename(columns = {'2': 'port', '3': 'dir'})
data = direct[3].str.split('\\', 1, expand = True)
# Out:
#                    2                                                  3
# 0     192.168.21.132  gt450-images-r\LRC\2021.10.21\LRC_2018_30651-5...
# 1     192.168.21.132       gt450-images-r\LRCLRC_2018_30651-57_#4_4.svs
# 2     192.168.21.132  gt450-images-r\LRC\2021.08.13\LRC.19.1-2.#11-2...
# 3     192.168.21.132  gt450-images-r\LRC\2021.08.13\LRC.19.10-22.#7\...
# 4     192.168.21.132  gt450-images-r\LRC\2021.08.13\LRC.19.10-22.#7\...
# ...              ...                                                ...
# 7545  192.168.21.132  gt450-images-r\LRC\2021.10.21\LRC_2018_30646-4...
# 7546  192.168.21.132  gt450-images-r\LRC\2021.10.21\LRC_2018_30646-4...
# 7547  192.168.21.132  gt450-images-r\LRC\2021.10.21\LRC_2018_30649-5...
# 7548  192.168.21.132  gt450-images-r\LRC\2021.10.21\LRC_2018_30651-5...
# 7549  192.168.21.132  gt450-images-r\LRC\2021.10.21\LRC_2018_30651-5...
#
# [7550 rows x 2 columns]

# %%
data = direct[3].str.split('\\', 1, expand = True)

# %%
data
# Out:
#                    0                                                  1
# 0     gt450-images-r  LRC\2021.10.21\LRC_2018_30651-57_#4LRC_2018_30...
# 1     gt450-images-r                      LRCLRC_2018_30651-57_#4_4.svs
# 2     gt450-images-r           LRC\2021.08.13\LRC.19.1-2.#11-2-2_20.svs
# 3     gt450-images-r    LRC\2021.08.13\LRC.19.10-22.#7\10.#110-2_14.svs
# 4     gt450-images-r  LRC\2021.08.13\LRC.19.10-22.#7\11-16.#211-16-2...
# ...              ...                                                ...
# 7545  gt450-images-r  LRC\2021.10.21\LRC_2018_30646-48_#2_1_10_02563...
# 7546  gt450-images-r  LRC\2021.10.21\LRC_2018_30646-48_#2_1_11_02593...
# 7547  gt450-images-r  LRC\2021.10.21\LRC_2018_30649-50_#1_1_13_03023...
# 7548  gt450-images-r  LRC\2021.10.21\LRC_2018_30651-57_#4LRC_2018_30...
# 7549  gt450-images-r  LRC\2021.10.21\LRC_2018_30651-57_#4LRC_2018_30...
#
# [7550 rows x 2 columns]

# %%
direct
# Out:
#                    2                                                  3
# 0     192.168.21.132  gt450-images-r\LRC\2021.10.21\LRC_2018_30651-5...
# 1     192.168.21.132       gt450-images-r\LRCLRC_2018_30651-57_#4_4.svs
# 2     192.168.21.132  gt450-images-r\LRC\2021.08.13\LRC.19.1-2.#11-2...
# 3     192.168.21.132  gt450-images-r\LRC\2021.08.13\LRC.19.10-22.#7\...
# 4     192.168.21.132  gt450-images-r\LRC\2021.08.13\LRC.19.10-22.#7\...
# ...              ...                                                ...
# 7545  192.168.21.132  gt450-images-r\LRC\2021.10.21\LRC_2018_30646-4...
# 7546  192.168.21.132  gt450-images-r\LRC\2021.10.21\LRC_2018_30646-4...
# 7547  192.168.21.132  gt450-images-r\LRC\2021.10.21\LRC_2018_30649-5...
# 7548  192.168.21.132  gt450-images-r\LRC\2021.10.21\LRC_2018_30651-5...
# 7549  192.168.21.132  gt450-images-r\LRC\2021.10.21\LRC_2018_30651-5...
#
# [7550 rows x 2 columns]

# %%
direct.iloc[:7549, [2, 3]]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# C:\Users\DSTARA~1\AppData\Local\Temp/ipykernel_24048/4105223437.py in <module>
# ----> 1 direct.iloc[:7549, [2, 3]]
#
# c:\users\dstarasov\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# c:\users\dstarasov\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1504     def _getitem_tuple(self, tup: tuple):
#    1505
# -> 1506         self._has_valid_tuple(tup)
#    1507         with suppress(IndexingError):
# ...

# %%
direct = dataframe['directory'].str.split("\\", 3, expand=True)

# %%
direct.shape
# Out:
# (7547, 2)

# %%
direct.rename(index={0:'Date'}, columns={2:'SM'}, inplace=True)

# %%
direct.head()
# Out:
#                   SM                                                  3
# Date  192.168.21.132  gt450-images-r\LRC\2021.08.13\LRC.19.1-2.#11-2...
# 3     192.168.21.132  gt450-images-r\LRC\2021.08.13\LRC.19.10-22.#7\...
# 4     192.168.21.132  gt450-images-r\LRC\2021.08.13\LRC.19.10-22.#7\...
# 5     192.168.21.132  gt450-images-r\LRC\2021.08.13\LRC.19.10-22.#7\...
# 6     192.168.21.132  gt450-images-r\LRC\2021.08.13\LRC.19.10-22.#7\...

# %%
import os
from subprocess import run, STDOUT, PIPE
L = 0
path = "\\\\192.168.21.132\gt450-images-r\LRC"
cmd = 'C:/Program Files/RCUD/b_label_function/application/b_label_function.exe'
for root, dirs, files in os.walk(path):
    for file in files:
        if file.endswith(".svs"):
            L+=1 
            dir_name = root +'&'+ file
            print(cmd + '  ' + root + '//'+ file + '  ' +  dir_name[32:-3].replace('\\', '&') + "png" , L)
# Out:
# C:/Program Files/RCUD/b_label_function/application/b_label_function.exe  \\192.168.21.132\gt450-images-r\LRC\2021.08.13\LRC.19.1-2.#1//1-2-2_20.svs  LRC&2021.08.13&LRC.19.1-2.#1&1-2-2_20.png 1
# C:/Program Files/RCUD/b_label_function/application/b_label_function.exe  \\192.168.21.132\gt450-images-r\LRC\2021.08.13\LRC.19.10-22.#7\10.#1//10-2_14.svs  LRC&2021.08.13&LRC.19.10-22.#7&10.#1&10-2_14.png 2
# C:/Program Files/RCUD/b_label_function/application/b_label_function.exe  \\192.168.21.132\gt450-images-r\LRC\2021.08.13\LRC.19.10-22.#7\11-16.#2//11-16-2_12.svs  LRC&2021.08.13&LRC.19.10-22.#7&11-16.#2&11-16-2_12.png 3
# C:/Program Files/RCUD/b_label_function/application/b_label_function.exe  \\192.168.21.132\gt450-images-r\LRC\2021.08.13\LRC.19.10-22.#7\11-16.#2//11-16-2_13.svs  LRC&2021.08.13&LRC.19.10-22.#7&11-16.#2&11-16-2_13.png 4
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\DSTARA~1\AppData\Local\Temp/ipykernel_24048/45298611.py in <module>
#       1 df= { 'col3': [all_files]}
#       2 df1 = pd.DataFrame(df)
# ----> 3 df2 [['path','name_svs']] = pd.DataFrame(df1.all_files.tolist(), index= df1.index)
#
# c:\users\dstarasov\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'all_files'

# %%
import os, os.path

all_files = []

for root, dirs, files in os.walk("\\\\192.168.23.132/gt450-images-r/LRC"):
    for f in files:
        fullpath = os.path.join(root, f)
        if os.path.splitext(fullpath)[1] == '.svs':
            all_files.append(fullpath)
for i in all_files:
    i = i.replace("\\",'/')
    os.system("Program Files/RCUD/b_label_function/application/b_label_function.exe "+ i + " " + '_'.join(i.split("/")[-4:])[:-3] + "png")
    break

# %%
FROM python
# Out:
#   File "C:\Users\DSTARA~1\AppData\Local\Temp/ipykernel_24048/2233362015.py", line 1
#     FROM python
#          ^
# SyntaxError: invalid syntax
