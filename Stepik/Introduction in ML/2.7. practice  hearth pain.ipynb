# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import tree
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
df_train = pd.read_csv ('C:/Users/sdgro/Desktop/ARM-510/task/DS/27train_data_tree.csv')

# %%
df_train.head()
# Out:
#    sex  exang  num
# 0    1      1    1
# 1    1      1    1
# 2    1      0    1
# 3    1      0    0
# 4    1      0    1

# %%
y = df_train.num
X = df_train.drop(['num'], axis =1 )

# %%
clf = tree.DecisionTreeClassifier( criterion  = 'entropy')

# %%
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
tree.plot_tree(clf, class_names = ['negative', 'Positive'], feature_names = list(X), filled = True)
# Out:
# [Text(167.4, 181.2, 'exang <= 0.5\nentropy = 0.996\nsamples = 238\nvalue = [128, 110]\nclass = negative'),
#  Text(83.7, 108.72, 'sex <= 0.5\nentropy = 0.903\nsamples = 157\nvalue = [107, 50]\nclass = negative'),
#  Text(41.85, 36.23999999999998, 'entropy = 0.612\nsamples = 53\nvalue = [45, 8]\nclass = negative'),
#  Text(125.55000000000001, 36.23999999999998, 'entropy = 0.973\nsamples = 104\nvalue = [62, 42]\nclass = negative'),
#  Text(251.10000000000002, 108.72, 'sex <= 0.5\nentropy = 0.826\nsamples = 81\nvalue = [21, 60]\nclass = Positive'),
#  Text(209.25, 36.23999999999998, 'entropy = 0.954\nsamples = 16\nvalue = [6, 10]\nclass = Positive'),
#  Text(292.95, 36.23999999999998, 'entropy = 0.779\nsamples = 65\nvalue = [15, 50]\nclass = Positive')]

# %%
l_nodel = clf.tree_.children_left[0]
l_nodel
# Out:
# 1

# %%
l_noder = clf.tree_.children_right[0]
l_noder
# Out:
# 4

# %%
n = clf.tree_.n_node_samples[l_node]
n
# Out:
# 157

# %%
e = clf.tree_.impurity[l_node]
e
# Out:
# 0.9027113410339267

# %%
l_noder = clf.tree_.children_right[0]
l_noder
# Out:
# 4

# %%
n = clf.tree_.n_node_samples[l_noder]
n
# Out:
# 81

# %%
e = clf.tree_.impurity[l_noder]
e
# Out:
# 0.8256265261578954

# %%
# !pip install openslide-python
